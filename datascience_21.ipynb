# %%
import matplotlib.pyplot as plt
data=[34,18,100,27,54,52,93,59,61,87,68,85,78,82,91]
plt.boxplot(data,vert=0,patch_artist=True)
plt.show()

# %%
import matplotlib.pyplot as plt
data1=[72,76,24,14,67,52,75,78,31,32]
data2=[62,5,91,25,36,32,96,95,30,90]
data3=[23,89,12,78,72,89,25,69,68,86]
bdata=(data1,data2,data3)
box=plt.boxplot(bdata,vert=1,patch_artist=True)
colors=['green','red','pink']
for p, color in zip(box['boxes'],colors):
    p.set_facecolor(color)
plt.show()

# %%
import matplotlib.pyplot as plt
data1=[72,76,24,14,67,52,75,78,31,32]
box=plt.boxplot(data1,vert=0,patch_artist=True)
colors='black'
for p in box['boxes']:
    p.set_facecolor(colors)
plt.show()

# %%
import matplotlib.pyplot as plt
umemp_rate=[6.1,5.8,5.7,5.7,5.8,5.6,5.5,5.3,5.2,5.2]
index_price=[1500,1520,1525,1523,1515,1540,1547,1560,1555,1565]
plt.scatter(umemp_rate,index_price,c='b')
plt.xlabel('umemp_rate',fontsize=16)
plt.ylabel('index_price',fontsize=16)
plt.title('Relationship between unemployement Rate and stock index price',fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
data=[19,26,25,37,32,28,22,23,29,34,39,31]
box=plt.boxplot(data,vert=0,patch_artist=True)
colors='black'
for p in box['boxes']:
    p.set_facecolor(colors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
clas=['I','II','III','IV','V','VI','VII','VIII','IX','X']
strength=[40,43,45,47,49,38,50,37,43,39]
colors=['red','yellow','green','blue','pink','orange','violet','grey','cyan','black']
plt.bar(clas,strength,color=colors,align='center')
plt.xlabel(clas)
plt.ylabel(strength)
plt.show()

# %%
import pandas as pd
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s)
print(s.iloc[1:4])
print(s.loc['b':'e'])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# b    2
# c    3
# d    4
# dtype: int64
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
import pandas as pd
s=pd.Series({'Jan':31,'Feb':28,'March':31,"April":30})
print(s)
# Out:
# Jan      31
# Feb      28
# March    31
# April    30
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(-10,10,1)
y=x**2
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
weights=[78,72,69,81,63,67,65,79,74,71,83,71,79,80]
plt.hist(weights,bins=[50,55,60,65,70,75,80,85],color='pink',edgecolor='violet')
plt.title('Histogram of muffin weights')
plt.xlabel('Weight in grams')
plt.ylabel('Frequency')
plt.show()

# %%
print('devipriya')
# Out:
# devipriya

# %%
print('aaliya')
# Out:
# aaliya

# %%
print('amina')
# Out:
# amina

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.neighbors import kNeighborsClassifier
from sklearn.model_selection import classification_report,confusion_matrix
d1={'BMI':[33.6,26.6,23.4,43.1,35.3,35.9,36.7,25.7,23.3,31],'age':[50,30,40,67,45,46,29,56],'sugar':[1,0,0,0,1,1,1,0,0,1]}
data1=pd.DataFrame(d1)
data1.to_csv("New Dataset")
print(data1)
col=data1['sugar'].map({0:'blue',1:'read'})
plt.scatter(data1['BMI'],data1['age'],color=col,s=100)
plt.title('BMI vs Age',fontsize=14)
plt.xlabel('BMI',fontsize=14)
plt.ylabel('Age',fontsize=14)
plt.scatter([],[],color='blue',label='sugar=0')
plt.scatter([],[],color='red',label='sugar=1')
plt.scatter(title='sugar level')
plt.grid(True)
plt.show()
x=data1(['BMI','Age'])
y=data1['Sugar']
scalar=preprocessing.StandardScalar().fit(x)
x.scaled=scalar.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,stratify=y,random_state=0)
knn=KNeighborsClssifier(n-neighbor)=3
knn.fit(c_train,y_train)
y_pred=knn.predict(x_test)
new_data=np.array([[43.6,40]])
new_data_scaled=scalar.transform(new_data)
pred=knn.predict(new_data_scaled)
print( f"The predicted cklassfor BMI=43.6 nad Age=40 is:"{preds[0]}" )
if pred[0]==0;
      print("The person has no sugar")
else
       print("The person has sugar")
cont_matrix=confusion_matrix(y_test,y_pred)
print("Confusion matrix")
print(cont_matrix)
# Out:
#   Input In [4]
#     knn=KNeighborsClssifier(n-neighbor)=3
#         ^
# SyntaxError: cannot assign to function call

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix

d1={'BMI':[33.6,26.6,23.4,43.1,35.3,35.9,36.7,25.7,23.3,31],'Age':[50,30,40,67,23,67,45,46,29,56],'Sugar':[1,0,0,0,1,1,1,0,0,1] }
data1=pd.DataFrame(d1)
data1.to_csv("New Dataset")
print(data1)
col=data1['Sugar'].map({0:'blue',1:'red'})
plt.scatter(data1 ['BMI'],data1 ['Age'],color=col,s=100)
plt.title('BMI vs Age',fontsize=14)
plt.xlabel('BMI',fontsize=14)
plt.ylabel('Age',fontsize=14)
plt.scatter([],[],color='blue',label='sugar=0')
plt.scatter([],[],color='red',label='sugar=1')
plt.legend(title='sugar level')
plt.grid(True)
plt.show()

x=data1[['BMI','Age']]
y=data1['Sugar']

scalar=preprocessing.StandardScaler().fit(x)
x_scaled=scalar.fit_transform(x)
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.3,stratify=y,random_state=0)
knn=KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
new_data=np.array([[43.6,40]])
newdata_scaled=scalar.transform(new_data)
pred=knn.predict(newdata_scaled)

print( f"The predicted cklassfor BMI=43.6 nad Age=40 is:{pred[0]} ")
if pred[0]==0:
    print("The person has no sugar")
else:
    print("The person has sugar")
cont_matrix=confusion_matrix(y_test,y_pred)
print("Confusion matrix")
print(cont_matrix)
# Out:
#     BMI  Age  Sugar
# 0  33.6   50      1
# 1  26.6   30      0
# 2  23.4   40      0
# 3  43.1   67      0
# 4  35.3   23      1
# 5  35.9   67      1
# 6  36.7   45      1
# 7  25.7   46      0
# 8  23.3   29      0
# 9  31.0   56      1
# The predicted cklassfor BMI=43.6 nad Age=40 is:1
# The person has sugar
# Confusion matrix
# [[2 0]
#  [0 1]]
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

tennisdata={'Outlook':['Sunny','Overcast','Rainy','Rainy','Rainy','Overcast','Sunny','Sunny','Rainy','Sunny','Sunny','Overcast','Overcast','Rainy'],
            'Temperature':['Hot','Hot','Hot','Mild', 'Cool','Cool','Cool','Mild','Cool','Mild','Mild','Mild','Hot','Mild'],
            'Humidity':['High','High','High','High','Normal','Normal','Normal','High','Normal','Normal','Normal','High','Normal','High'],
            'Windy':['False','True','False','False','False','True','True','False','False','False','True','True','False','True'],
            'PlayTennis':['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']}
data1=pd.read_csv('tennisdata.csv')
print(data1)
x=data1.drop('Play Tennis',axis=1).copy()
y=data1['PlayTennis']
print("\n",x)
print("\n",y)

le_outlook=LabelEncoder()
x.Outlook=le.outlook.fit_transform(x.Outlook)
le_Temperature=LabelEncoder()
x.Temperature=le_Temperature.fit_transform(x.Temperature)
le.Humidity=LabelEncoder()
x.Humidity=le_Humidity.fit_transform(x.Humidity)
le_windy=LabelEncoder()
x.windy=le_windy.fit_transform(x.windy)
le_PlayTennis=LabelEncoder()
y=le_PlayTennis,fit_transform(y)
print("\n",x)
print("\n",y)

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,stratify=y,random_state=0)
classifier=CategoricalNB()
classifier.fit(x_train,y_train)
print("Accuracy is :", accuracy=score(classifer.predict(x_test),(y_test)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 12>()
#       5 from sklearn.metrics import accuracy_score
#       7 tennisdata={'Outlook':['Sunny','Overcast','Rainy','Rainy','Rainy','Overcast','Sunny','Sunny','Rainy','Sunny','Sunny','Overcast','Overcast','Rainy'],
#       8             'Temperature':['Hot','Hot','Hot','Mild', 'Cool','Cool','Cool','Mild','Cool','Mild','Mild','Mild','Hot','Mild'],
#       9             'Humidity':['High','High','High','High','Normal','Normal','Normal','High','Normal','Normal','Normal','High','Normal','High'],
#      10             'Windy':['False','True','False','False','False','True','True','False','False','False','True','True','False','True'],
#      11             'PlayTennis':['No','No','Yes','Yes','Yes','No','Yes','No','Yes','Yes','Yes','Yes','Yes','No']}
# ---> 12 data1=pd.read_csv('tennisdata.csv')
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Use the dictionary directly
tennisdata = {
    'Outlook': ['Sunny', 'Overcast', 'Rainy', 'Rainy', 'Rainy', 'Overcast', 'Sunny', 'Sunny', 'Rainy', 'Sunny', 'Sunny', 'Overcast', 'Overcast', 'Rainy'],
    'Temperature': ['Hot', 'Hot', 'Hot', 'Mild', 'Cool', 'Cool', 'Cool', 'Mild', 'Cool', 'Mild', 'Mild', 'Mild', 'Hot', 'Mild'],
    'Humidity': ['High', 'High', 'High', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'Normal', 'Normal', 'High', 'Normal', 'High'],
    'Windy': ['False', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'False', 'True'],
    'PlayTennis': ['No', 'No', 'Yes', 'Yes', 'Yes', 'No', 'Yes', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'No']
}

# Create DataFrame
data = pd.DataFrame(tennisdata)

# Features and target
x = data.drop('PlayTennis', axis=1).copy()
y = data['PlayTennis']

# Label Encoding
le_outlook = LabelEncoder()
x['Outlook'] = le_outlook.fit_transform(x['Outlook'])

le_temperature = LabelEncoder()
x['Temperature'] = le_temperature.fit_transform(x['Temperature'])

le_humidity = LabelEncoder()
x['Humidity'] = le_humidity.fit_transform(x['Humidity'])

le_windy = LabelEncoder()
x['Windy'] = le_windy.fit_transform(x['Windy'])

le_play = LabelEncoder()
y = le_play.fit_transform(y)

# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, stratify=y, random_state=0)

# Train the model
classifier = CategoricalNB()
classifier.fit(x_train, y_train)

# Predict and evaluate
y_pred = classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy is:", accuracy)
# Out:
# Accuracy is: 0.3333333333333333

# %%
import pandas as pd
from io import StringIO
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Your CSV data as a multi-line string
csv_data = """Outlook,Temperature,Humidity,Windy,PlayTennis
Sunny,Hot,High,False,No
Overcast,Hot,High,True,No
Rainy,Hot,High,False,Yes
Rainy,Mild,High,False,Yes
Rainy,Cool,Normal,False,Yes
Overcast,Cool,Normal,True,No
Sunny,Cool,Normal,True,Yes
Sunny,Mild,High,False,No
Rainy,Cool,Normal,False,Yes
Sunny,Mild,Normal,False,Yes
Sunny,Mild,Normal,True,Yes
Overcast,Mild,High,True,Yes
Overcast,Hot,Normal,False,Yes
Rainy,Mild,High,True,No
"""

# Load data from the string as if it were a CSV file
data = pd.read_csv(StringIO(csv_data))

# Separate features and target
X = data.drop('PlayTennis', axis=1)
y = data['PlayTennis']

# Encode categorical features
le_outlook = LabelEncoder()
X['Outlook'] = le_outlook.fit_transform(X['Outlook'])

le_temperature = LabelEncoder()
X['Temperature'] = le_temperature.fit_transform(X['Temperature'])

le_humidity = LabelEncoder()
X['Humidity'] = le_humidity.fit_transform(X['Humidity'])

le_windy = LabelEncoder()
X['Windy'] = le_windy.fit_transform(X['Windy'])

# Encode target variable
le_play = LabelEncoder()
y = le_play.fit_transform(y)

# Split into train and test sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, stratify=y, random_state=0
)

# Train Categorical Naive Bayes
clf = CategoricalNB()
clf.fit(X_train, y_train)

# Predict on test set
y_pred = clf.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.3333333333333333
